# %% [markdown]
# Pandas
#
# Выполнил:6131 010402D, Макаров Андрей Романович
#
# Датасет:
# Набор данных о вине — это классический и очень простой набор данных для классификации нескольких классов.
#
# Классы
# 3
#
# Образцы на класс
# [59,71,48]
#
# Всего образцов
# 178
#
# Размерность
# 13

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_wine
data = load_wine()
df = pd.DataFrame(data.data, columns=data.feature_names)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Далее выполним следующие шаги:
# 2.1 вывод таблицы
#
# 2.2 вывод первых n элементов таблицы
#
# 2.3 вывод последних n элементов таблицы
#
# 2.4 .describe()
#
# 2.5 считывание значения конкретной ячейки (с конкретным индексом из конкретной колонки) всеми известными вам способами
#
# 2.6 фильтрация строк по диапазону индекса
#
# 2.7 фильтрация набора данных по какому-либо условию
#
# 2.8. работа с пропущенными значениями (если они есть): удаление строк с пропущенными значениями, заполнение пропущенных значений средним значением по колонке. Если пропущенных значений нет — намеренно их "генерируете", прибивая какие-то куски данных в np.nan
#
# 2.9. создание нового поля вычисленного на основе значений других полей:
#
# 2.9.1 через выражение на базе имеющихся колонок,
#
# 2.9.2 через DataFrame.apply
#
# 2.9.3 через Series.apply
#
# 2.10 сортировка по какому-либо из полей
#
# 2.11 вычислить несколько статистик по колонкам (используйте встроенные агрегатные функции — любые на выбор)
#
# 2.12 .value_counts()
#
# 2.13 Вывод уникальных значений колонки через .unique()
#
# 2.14 Удалите текущий индекс и создайте новый индекс на базе новой колонки, которая для этого лучше всего подходит

# %%
#Вывели первые 10
df.head(10)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
# 5    14.20        1.76  2.45               15.2      112.0           3.27
# 6    14.39        1.87  2.45               14.6       96.0           2.50
# 7    14.06        2.15  2.61               17.6      121.0           2.60
# 8    14.83        1.64  2.17               14.0       97.0           2.80
# 9    13.86        1.35  2.27               16.0       98.0           2.98
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# ...

# %%
#Вывели первые 10
df.tail(10)
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 168    13.58        2.58  2.69               24.5      105.0           1.55
# 169    13.40        4.60  2.86               25.0      112.0           1.98
# 170    12.20        3.03  2.32               19.0       96.0           1.25
# 171    12.77        2.39  2.28               19.5       86.0           1.39
# 172    14.16        2.51  2.48               20.0       91.0           1.68
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# ...

# %%
df.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
#Считывание значение конкретной ячейки 
#(с конкретным индексом из конкретной колонки) 
#всеми известными вам способами
df.loc[2][2]
# Out:
# 2.67

# %%
df.iloc[1]["malic_acid"]
# Out:
# 1.78

# %%
df.at[10,'alcalinity_of_ash']
# Out:
# 18.0

# %%
#Фильтрация строк по диапазону индекса 
df[2:5]
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# 2                          3.17   1185.0
# 3                          3.45   1480.0
# 4                          2.93    735.0

# %%
df[20:50]
# Out:
#     alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 20    14.06        1.63  2.28               16.0      126.0           3.00
# 21    12.93        3.80  2.65               18.6      102.0           2.41
# 22    13.71        1.86  2.36               16.6      101.0           2.61
# 23    12.85        1.60  2.52               17.8       95.0           2.48
# 24    13.50        1.81  2.61               20.0       96.0           2.53
# 25    13.05        2.05  3.22               25.0      124.0           2.63
# 26    13.39        1.77  2.62               16.1       93.0           2.85
# 27    13.30        1.72  2.14               17.0       94.0           2.40
# 28    13.87        1.90  2.80               19.4      107.0           2.95
# 29    14.02        1.68  2.21               16.0       96.0           2.65
# 30    13.73        1.50  2.70               22.5      101.0           3.00
# ...

# %%
#Фильтрация набора данных по какому-либо условию
df[ df.total_phenols > 3 ]
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 5      14.20        1.76  2.45               15.2      112.0           3.27
# 13     14.75        1.73  2.39               11.4       91.0           3.10
# 14     14.38        1.87  2.38               12.0      102.0           3.30
# 18     14.19        1.59  2.48               16.5      108.0           3.30
# 40     13.56        1.71  2.31               16.2      117.0           3.15
# 42     13.88        1.89  2.59               15.0      101.0           3.25
# 46     14.38        3.59  2.28               16.0      102.0           3.25
# 47     13.90        1.68  2.12               16.0      101.0           3.10
# 52     13.82        1.75  2.42               14.0      111.0           3.88
# 56     14.22        1.70  2.30               16.3      118.0           3.20
# ...

# %%
#Работа с пропущенными значениями
df_no_nan = df.dropna()
df_no_nan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %%
#Заполняем сдедним значением по колонке 
mean_df = df.fillna(df.mean())
mean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %%
#Создание нового поля вычисленного на основе значений других полей
#Столбец по отношениям щелочи и магния

# %%
df["alcalinity_of_ash/magnesium"] = df["alcalinity_of_ash"]/df["magnesium"]
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
#Добавим через DataFrame.apply
df['apply_df_stolb'] = df.apply( lambda row: row['alcalinity_of_ash/magnesium'] * row['alcohol'], axis = 1 )
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
#Добавим через Series.apply
df['Series_apply_df_stolb'] = df['ash'].apply( lambda val: val / df['ash'].mean() )
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
#2.10 сортировка по какому-либо из полей
#2.11 вычислить несколько статистик по колонкам (используйте встроенные агрегатные функции — любые на выбор)
print(df['ash'].mean())
print(df['alcalinity_of_ash'].max())
print(df['magnesium'].min())
print(df['nonflavanoid_phenols'].median())
# Out:
# 2.3665168539325845
# 30.0
# 70.0
# 0.34

# %%
df.count()
# Out:
# alcohol                         178
# malic_acid                      178
# ash                             178
# alcalinity_of_ash               178
# magnesium                       178
# total_phenols                   178
# flavanoids                      178
# nonflavanoid_phenols            178
# proanthocyanins                 178
# color_intensity                 178
# hue                             178
# od280/od315_of_diluted_wines    178
# proline                         178
# alcalinity_of_ash/magnesium     178
# apply_df_stolb                  178
# Series_apply_df_stolb           178
# dtype: int64

# %%
#Уникальные значения
print(len(df['apply_df_stolb'].unique()))
print(df['apply_df_stolb'].unique())
# Out:
# 177
# [1.74793701 1.4784     2.42352475 2.13642478 2.35627119 1.92714286
#  2.18847917 2.04509091 2.14041237 2.26285714 2.41714286 2.49701053
#  2.47191011 1.8478022  1.69176471 2.09317857 2.38333333 2.40521739
#  2.16791667 1.78731034 1.78539683 2.35782353 2.25332673 2.40768421
#  2.8125     2.63104839 2.31805376 2.40531915 2.51474766 2.33666667
#  3.05866337 2.44696226 2.26246154 2.03272727 2.33354545 2.7634
#  1.87127273 2.39693878 2.06719388 1.4664375  1.87753846 2.8012
#  2.06138614 2.24951456 2.07336449 2.41954054 2.25568627 2.2019802
#  2.57359223 2.24588889 1.75891304 2.53059574 1.74306306 2.04753913
#  1.90962712 2.39637931 1.96428814 2.18894118 2.12151852 1.49002273
#  1.95326733 2.12352    2.61765957 2.70149425 2.22336538 2.28466327
#  2.52115385 3.10835897 2.06163636 1.35846358 2.43413592 4.02906977
#  3.72137931 2.80359712 2.48673267 1.92329897 2.42418605 1.90285714
#  1.34179412 2.89207921 2.65116279 2.78065116 3.71692308 3.45441176
# ...

# %%
df.value_counts()
# Out:
# alcohol  malic_acid  ash   alcalinity_of_ash  magnesium  total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity  hue   od280/od315_of_diluted_wines  proline  alcalinity_of_ash/magnesium  apply_df_stolb  Series_apply_df_stolb
# 11.03    1.51        2.20  21.5               85.0       2.46           2.17        0.52                  2.01             1.90             1.71  2.87                          407.0    0.252941                     2.789941        0.929636                 1
# 13.68    1.83        2.36  17.2               104.0      2.42           2.69        0.42                  1.97             3.84             1.23  2.87                          990.0    0.165385                     2.262462        0.997246                 1
# ...

# %%
# Cортировка по какому-либо из полей
df.fillna(0).sort_values('alcalinity_of_ash', ascending=False).head(10)
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 73     12.99        1.67  2.60               30.0      139.0           3.30
# 127    11.79        2.13  2.78               28.5       92.0           2.13
# 121    11.56        2.05  3.23               28.5      119.0           3.18
# 157    12.45        3.03  2.64               27.0       97.0           1.90
# 122    12.42        4.43  2.73               26.5      102.0           2.20
# 87     11.65        1.67  2.62               26.0       88.0           1.92
# 152    13.11        1.90  2.75               25.5      116.0           2.20
# 71     13.86        1.51  2.67               25.0       86.0           2.95
# 169    13.40        4.60  2.86               25.0      112.0           1.98
# 158    14.34        1.68  2.70               25.0       98.0           2.80
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# ...

# %%
#Удалите текущий индекс и создайте новый индекс на базе новой колонки, 
# которая для этого лучше всего подходит
new_df = df.copy()
new_df.index = new_df['ash']
new_df
# Out:
#       alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# ash
# 2.43    14.23        1.71  2.43               15.6      127.0           2.80
# 2.14    13.20        1.78  2.14               11.2      100.0           2.65
# 2.67    13.16        2.36  2.67               18.6      101.0           2.80
# 2.50    14.37        1.95  2.50               16.8      113.0           3.85
# 2.87    13.24        2.59  2.87               21.0      118.0           2.80
# ...       ...         ...   ...                ...        ...            ...
# 2.45    13.71        5.65  2.45               20.5       95.0           1.68
# 2.48    13.40        3.91  2.48               23.0      102.0           1.80
# 2.26    13.27        4.28  2.26               20.0      120.0           1.59
# 2.37    13.17        2.59  2.37               20.0      120.0           1.65
# 2.74    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
#Продемонстрировать работу .groupby, на основе группировок в groupby 
#вычисляете агрегатные функции по одной или нескольким колонкам. 
df.groupby('flavanoids').count()
# Out:
#             alcohol  malic_acid  ash  alcalinity_of_ash  magnesium  \
# flavanoids
# 0.34              1           1    1                  1          1
# 0.47              2           2    2                  2          2
# 0.48              1           1    1                  1          1
# 0.49              1           1    1                  1          1
# 0.50              2           2    2                  2          2
# ...             ...         ...  ...                ...        ...
# 3.69              1           1    1                  1          1
# 3.74              1           1    1                  1          1
# 3.75              1           1    1                  1          1
# 3.93              1           1    1                  1          1
# 5.08              1           1    1                  1          1
#
#             total_phenols  nonflavanoid_phenols  proanthocyanins  \
# flavanoids
# 0.34                    1                     1                1
# ...

# %%
df.groupby('magnesium').mean().pivot(columns='total_phenols', values='flavanoids')
# Out:
# total_phenols  1.400000  1.510000  1.548000  1.600000  1.815000  1.850000  \
# magnesium
# 70.0                NaN       NaN       NaN       NaN       NaN       NaN
# 78.0                NaN       NaN       NaN       NaN       NaN       NaN
# 80.0                NaN       NaN     1.366       NaN       NaN       NaN
# 81.0                NaN       NaN       NaN      1.50       NaN       NaN
# 82.0                NaN       NaN       NaN       NaN       NaN       NaN
# 84.0                NaN       NaN       NaN       NaN       NaN       NaN
# 85.0                NaN       NaN       NaN       NaN       NaN       NaN
# 86.0                NaN       NaN       NaN       NaN       NaN       NaN
# 87.0                NaN       NaN       NaN       NaN       NaN       NaN
# 88.0                NaN       NaN       NaN       NaN       NaN       NaN
# 89.0                NaN       NaN       NaN       NaN       NaN       NaN
# ...

# %%
pd.pivot_table(df, index='magnesium')
# Out:
#            Series_apply_df_stolb  alcalinity_of_ash  \
# magnesium
# 70.0                    0.971893          23.600000
# 78.0                    0.863435          19.533333
# 80.0                    0.927101          19.540000
# 81.0                    0.980344          18.500000
# 82.0                    1.009923          21.000000
# 84.0                    1.019783          22.200000
# 85.0                    0.908508          19.833333
# 86.0                    0.923874          20.463636
# 87.0                    0.901466          20.666667
# 88.0                    0.926711          19.892308
# 89.0                    1.041193          19.800000
# 90.0                    0.950764          21.400000
# 91.0                    1.028938          15.700000
# 92.0                    0.971047          20.280000
# 93.0                    1.043728          19.050000
# 94.0                    0.995838          18.116667
# 95.0                    1.026826          18.366667
# ...

# %%
#Посчитать квантили распределения какого-либо вещественного признака 
# (с помощью numpy.quantile или numpy.percentile)
np.quantile(df['total_phenols'].fillna(0), 0.1)
# Out:
# 1.4709999999999999

# %%
df.quantile(0.1, numeric_only=True)
# Out:
# alcohol                          11.933000
# malic_acid                        1.247000
# ash                               2.000000
# alcalinity_of_ash                16.000000
# magnesium                        85.000000
# total_phenols                     1.471000
# flavanoids                        0.607000
# nonflavanoid_phenols              0.217000
# proanthocyanins                   0.854000
# color_intensity                   2.549000
# hue                               0.610000
# od280/od315_of_diluted_wines      1.580000
# proline                         406.700000
# alcalinity_of_ash/magnesium       0.143304
# apply_df_stolb                    1.907596
# Series_apply_df_stolb             0.845124
# Name: 0.1, dtype: float64

# %%
# Посчитать гистограмму какого-либо вещественного признака 
# (с помощью numpy.histogram). Значения гистограммы можете использовать
#  как вариант в качестве загрубленного 
# числового признака для заданий (4) или (5).
plt.hist(df['total_phenols'])
# Out:
# (array([ 4., 22., 26., 24., 20., 30., 33., 10.,  7.,  2.]),
#  array([0.98, 1.27, 1.56, 1.85, 2.14, 2.43, 2.72, 3.01, 3.3 , 3.59, 3.88]),
#  <BarContainer object of 10 artists>)

# %%
df.head(5)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
# ...

# %%
#Получить DataFrame с MultiIndex любым способом: через конструктор 
# (в документации увидите множество видов конструкторов для создания MultiIndex с нуля), 
# через read_sql / read_csv / readexcel, read*, через pivot_table, 
# через groupby или иными способами.
# Переставить местами уровни индекса
mult_ind = pd.pivot_table(df, index=['alcohol', 'ash'])
mult_ind
# Out:
#               Series_apply_df_stolb  alcalinity_of_ash  \
# alcohol ash
# 11.03   2.20               0.929636               21.5
# 11.41   2.50               1.056405               21.0
# 11.45   2.42               1.022600               20.0
# 11.46   1.82               0.769063               19.5
# 11.56   3.23               1.364875               28.5
# ...                             ...                ...
# 14.38   2.28               0.963441               16.0
#         2.38               1.005697               12.0
# 14.39   2.45               1.035277               14.6
# 14.75   2.39               1.009923               11.4
# 14.83   2.17               0.916959               14.0
#
#               alcalinity_of_ash/magnesium  apply_df_stolb  color_intensity  \
# alcohol ash
# 11.03   2.20                     0.252941        2.789941             1.90
# 11.41   2.50                     0.238636        2.722841             3.08
# ...

# %%
#Переставить местами уровни индекса
mult_ind.swaplevel(0, 1)
# Out:
#               Series_apply_df_stolb  alcalinity_of_ash  \
# ash  alcohol
# 2.20 11.03                 0.929636               21.5
# 2.50 11.41                 1.056405               21.0
# 2.42 11.45                 1.022600               20.0
# 1.82 11.46                 0.769063               19.5
# 3.23 11.56                 1.364875               28.5
# ...                             ...                ...
# 2.28 14.38                 0.963441               16.0
# 2.38 14.38                 1.005697               12.0
# 2.45 14.39                 1.035277               14.6
# 2.39 14.75                 1.009923               11.4
# 2.17 14.83                 0.916959               14.0
#
#               alcalinity_of_ash/magnesium  apply_df_stolb  color_intensity  \
# ash  alcohol
# 2.20 11.03                       0.252941        2.789941             1.90
# 2.50 11.41                       0.238636        2.722841             3.08
# ...

# %%
#Транспонировать таблицу (или создать новую другую) с MultiIndex
pd.DataFrame(mult_ind).T
# Out:
# alcohol                            11.03       11.41       11.45       11.46  \
# ash                                 2.20        2.50        2.42        1.82
# Series_apply_df_stolb           0.929636    1.056405    1.022600    0.769063
# alcalinity_of_ash              21.500000   21.000000   20.000000   19.500000
# alcalinity_of_ash/magnesium     0.252941    0.238636    0.208333    0.182243
# apply_df_stolb                  2.789941    2.722841    2.385417    2.088505
# color_intensity                 1.900000    3.080000    3.250000    2.900000
# flavanoids                      2.170000    2.010000    2.790000    2.580000
# hue                             1.710000    1.100000    0.800000    0.750000
# magnesium                      85.000000   88.000000   96.000000  107.000000
# malic_acid                      1.510000    0.740000    2.400000    3.740000
# nonflavanoid_phenols            0.520000    0.420000    0.320000    0.240000
# ...

# %%
#Удалить один из уровней индекса или добавить 
#новый уровень индекса (можно инициализированный константой)
mult_ind.reset_index(1)
# Out:
#           ash  Series_apply_df_stolb  alcalinity_of_ash  \
# alcohol
# 11.03    2.20               0.929636               21.5
# 11.41    2.50               1.056405               21.0
# 11.45    2.42               1.022600               20.0
# 11.46    1.82               0.769063               19.5
# 11.56    3.23               1.364875               28.5
# ...       ...                    ...                ...
# 14.38    2.28               0.963441               16.0
# 14.38    2.38               1.005697               12.0
# 14.39    2.45               1.035277               14.6
# 14.75    2.39               1.009923               11.4
# 14.83    2.17               0.916959               14.0
#
#          alcalinity_of_ash/magnesium  apply_df_stolb  color_intensity  \
# alcohol
# 11.03                       0.252941        2.789941             1.90
# 11.41                       0.238636        2.722841             3.08
# ...

# %%
#Продемонстировать работу .merge
df_new = pd.DataFrame({'alcohol': df.alcohol, 'stolb_': np.random.rand(df.alcohol.count())})
df_new
# Out:
#      alcohol    stolb_
# 0      14.23  0.026630
# 1      13.20  0.366786
# 2      13.16  0.642314
# 3      14.37  0.416305
# 4      13.24  0.086471
# ..       ...       ...
# 173    13.71  0.927884
# 174    13.40  0.441584
# 175    13.27  0.404588
# 176    13.17  0.166231
# 177    14.13  0.956849
#
# [178 rows x 2 columns]

# %%
df_merge = df.merge(df_new, left_on='alcohol', right_on='alcohol') 
df_merge
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      13.16        2.36  2.67               18.6      101.0           2.80
# 4      13.16        3.57  2.15               21.0      102.0           1.50
# ..       ...         ...   ...                ...        ...            ...
# 341    13.40        3.91  2.48               23.0      102.0           1.80
# 342    12.20        3.03  2.32               19.0       96.0           1.25
# 343    14.16        2.51  2.48               20.0       91.0           1.68
# 344    13.27        4.28  2.26               20.0      120.0           1.59
# 345    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
df_p1 = df[:2]
df_p2 = df[2:7]
df_3 = pd.concat([df_p1,df_p2])
df_3
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
# 5    14.20        1.76  2.45               15.2      112.0           3.27
# 6    14.39        1.87  2.45               14.6       96.0           2.50
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# ...

# %%
#Проитерировать dataframe построчно .iterrows(). Выполните что-то имеющее смысл внутри цикла
for i in df_3.iterrows():
    print(i)
# Out:
# (0, alcohol                           14.230000
# malic_acid                         1.710000
# ash                                2.430000
# alcalinity_of_ash                 15.600000
# magnesium                        127.000000
# total_phenols                      2.800000
# flavanoids                         3.060000
# nonflavanoid_phenols               0.280000
# proanthocyanins                    2.290000
# color_intensity                    5.640000
# hue                                1.040000
# od280/od315_of_diluted_wines       3.920000
# proline                         1065.000000
# alcalinity_of_ash/magnesium        0.122835
# apply_df_stolb                     1.747937
# Series_apply_df_stolb              1.026826
# Name: 0, dtype: float64)
# (1, alcohol                           13.200000
# malic_acid                         1.780000
# ash                                2.140000
# alcalinity_of_ash                 11.200000
# ...
